# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from feature_engine.selection import SmartCorrelatedSelection,DropCorrelatedFeatures

# %%
df=pd.read_csv('data.csv')

# %%
df.shape
# Out:
# (41846, 95)

# %% [markdown]
# # 1. Drop highly correlated variables

# %%
# we have 71 features after detecting the correlation
dcf=DropCorrelatedFeatures(threshold=0.7)
df_drop_correlation=dcf.fit_transform(df)
print(f"Total valid variables number: {df.shape[1]-1}\nDropped features due to correlation: {len(dcf.features_to_drop_)}\nkeep feautures {df_drop_correlation.shape[1]-1}" )
# Out:
# Total valid variables number: 94
# Dropped features due to correlation: 23
# keep feautures 71

# %%
print(f"Correlated groups of features:\n {dcf.correlated_feature_sets_}")
# Out:
# Correlated groups of features:
#  [{'discharge_created_datetime', 'Admission_Month'}, {'non_elective_admission_flag', 'IP_admission', 'IP_discharge'}, {'acuity_code', 'NEWS2_missing', 'place_of_incident', 'inj_or_ail', 'presenting_complaint_encoded', 'presenting_complaint_count', 'season_of_the_admission', 'source_of_ref_description', 'ae_unplanned_attendance', 'location', 'arrival_mode_description', 'attendancetype'}, {'comorbidity_acute_myocardial_infarction_flag.1', 'comorbidity_acute_myocardial_infarction_flag'}, {'readmission_flag_30_days_emergancy', 'readmission_flag_28_days_emergancy', 'emergency_readmission_non_pbr_30'}, {'readmission_flag_28_days', 'readmission_flag_30_days'}, {'specialty_spec_code_Surgical_Spec', 'specialty_spec_code_Medical_Spec'}, {'spell_dominant_proc_description', 'spell_dominant_proc_encoded'}, {'spell_primary_diagnosis_description', 'spell_primary_diagnosis_encoded'}, {'ward_code_admission_2', 'ward_code_admission_3'}, {'ward_type_admission', 'ward_type_discharge'}]

# %% [markdown]
# # 2. Feature selection for modelling

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel,SelectKBest
from sklearn.model_selection import train_test_split

# %%
#train test split for feature selection
X=df_drop_correlation.drop('spell_length_of_stay_hours',axis=1)
y_orgin=df_drop_correlation['spell_length_of_stay_hours']
# clips y by capping all values above its 95th percentile to that percentile value (627) to handle the extrem cases.
y_cliped = np.clip(y_orgin, None, y_orgin.quantile(0.95))
#transformtion
y_transfromed = np.log1p(y_cliped)
X_train, X_test, y_train, y_test=train_test_split(X,y_transfromed,test_size=0.2, random_state=42)

# %%
y_cliped.describe()
# Out:
# count    41846.000000
# mean        35.935239
# std         62.966064
# min          0.000000
# 25%          3.000000
# 50%          6.000000
# 75%         34.000000
# max        239.000000
# Name: spell_length_of_stay_hours, dtype: float64

# %%
fig,axes=plt.subplots(1,2,figsize=(10,4))
sns.histplot(y_orgin,ax=axes[0], bins=30)
sns.histplot(y_transfromed,ax=axes[1], bins=30)
axes[0].set_title('length of stay hours')
axes[1].set_title('length of stay hours (log1p transformation)')
fig.savefig('target_transformation.png')

# %%
# using random forest for feature selection
sel_=SelectFromModel(RandomForestRegressor(n_estimators=10,random_state=10))
sel_.fit(X_train,y_train)
# Out:
# SelectFromModel(estimator=RandomForestRegressor(n_estimators=10,
#                                                 random_state=10))

# %%
#there 15 features are high significant effect on y label
selected_f=X_train.columns[(sel_.get_support())]
print(f'{len(selected_f)} features are selected,\nthey are {selected_f}')
# Out:
# 15 features are selected,
# they are Index(['patient_age_on_admission', 'Admission_Hour', 'ward_code_admission_2',
#        'spell_dominant_proc_count', 'spell_secondary_diagnosis_encoded',
#        'spec_direc_Womens Health', 'hrg_sub_group_encoded',
#        'general_medical_practice_desc', 'IP_admission', 'ward_type_admission',
#        'spell_primary_diagnosis_description',
#        'spell_dominant_proc_description', 'discharge_letter_status',
#        'comorbidity_score', 'NEWS2_missing'],
#       dtype='object')

# %% [markdown]
# **check the correlation relationship with y label**

# %%
corr_with_y = X_train[selected_f].corrwith(y_train)

# %%
corr_sorted = corr_with_y.sort_values(ascending=False)
print(corr_sorted)
# Out:
# IP_admission                           0.513988
# spell_secondary_diagnosis_encoded      0.449396
# spell_primary_diagnosis_description    0.437281
# spell_dominant_proc_description        0.405424
# hrg_sub_group_encoded                  0.310789
# discharge_letter_status                0.282782
# comorbidity_score                      0.262378
# spec_direc_Womens Health               0.220033
# Admission_Hour                         0.114538
# spell_dominant_proc_count              0.114441
# general_medical_practice_desc          0.039308
# ward_type_admission                    0.032188
# patient_age_on_admission               0.011009
# ward_code_admission_2                 -0.211567
# NEWS2_missing                         -0.452329
# dtype: float64

# %%
#check the importance variables distribution
ss=pd.Series(sel_.estimator_.feature_importances_.ravel())
ss.hist(bins=30)
plt.ylabel("Number of features")
plt.xlabel('Feature importance')
# Out:
# Text(0.5, 0, 'Feature importance')

# %% [markdown]
# **The top 15 variables that have significant effect on target variable based on feature importance score**

# %%
#order the variables by Feature importance score
df_f_importance=pd.DataFrame({

    'feature_name':X_train.columns,
    'Feature_importance':sel_.estimator_.feature_importances_.ravel()
}
    )
df_f_importance=df_f_importance.sort_values(by='Feature_importance',ascending=False)
df_f_importance.head(15)
# Out:
#                            feature_name  Feature_importance
# 38                         IP_admission            0.263797
# 40  spell_primary_diagnosis_description            0.149847
# 6                        Admission_Hour            0.060558
# 70                        NEWS2_missing            0.056771
# 15            spell_dominant_proc_count            0.050992
# 43              discharge_letter_status            0.049863
# 41      spell_dominant_proc_description            0.047107
# 1              patient_age_on_admission            0.044203
# 19    spell_secondary_diagnosis_encoded            0.032226
# 39                  ward_type_admission            0.023686
# 30                hrg_sub_group_encoded            0.021119
# 45                    comorbidity_score            0.021061
# 13                ward_code_admission_2            0.019896
# 28             spec_direc_Womens Health            0.014468
# 37        general_medical_practice_desc            0.014156

# %%
dfsss=pd.read_csv('data/data1.csv',low_memory=False)

# %%
dfsss['patient_age_on_admission'].describe()
# Out:
# count    41846.000000
# mean        56.907470
# std         23.284725
# min          1.000000
# 25%         41.000000
# 50%         62.000000
# 75%         75.000000
# max        104.000000
# Name: patient_age_on_admission, dtype: float64

# %%
df['spell_primary_diagnosis_description']
# Out:
# 0        49.672466
# 1        49.672466
# 2        49.672466
# 3        49.672466
# 4        49.672466
#            ...
# 41841    56.999250
# 41842    56.971582
# 41843    56.941689
# 41844    56.913521
# 41845    56.888203
# Name: spell_primary_diagnosis_description, Length: 41846, dtype: float64

# %% [markdown]
# # 3. Modelling

# %% [markdown]
# ## XGboost & Random Forest

# %%
import xgboost as xgb
from sklearn.model_selection import KFold,cross_val_score
from sklearn.ensemble import RandomForestRegressor
import optuna
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import scipy.stats as stats

# %% [markdown]
# **Summary**
# - Train both XGboost and Random Forest(RF), I found the xgboost perform better compared to RF, and the best hyperparameters are:
# - 'n_estimators': 551, 'eta': 0.09999505543790956, 'max_depth': 4, 'min_child_weight': 7, 'gamma': 0.007863761012372683, 'subsample': 0.9073633957366012, 'colsample_bytree': 0.9023232725358237, 'lambda': 0.4625447729034002, 'alpha': 5.622304574316678}

# %%
X_train = np.array(X_train[selected_f])
y_train = np.array(y_train)
X_test = np.array(X_test[selected_f])
y_test = np.array(y_test)

# %% [markdown]
# **Tune the parameters by using top 15 features**

# %%
def objective(trial):

    
    model_name = trial.suggest_categorical("model", ["xgb", "rf"])

    
    n_estimators = trial.suggest_int("n_estimators", 300, 600)

    # =====================================================
    #  1：XGBoost
    # =====================================================
    if model_name == "xgb":


        params = {
            "objective": "reg:squarederror",
            "tree_method": "hist",
            
            "eta": trial.suggest_float("eta", 0.01, 0.1),
            "max_depth": trial.suggest_int("max_depth", 2, 4),
            "min_child_weight": trial.suggest_int("min_child_weight", 3, 15),
            "gamma": trial.suggest_float("gamma", 0.0, 10.0),

            "subsample": trial.suggest_float("subsample", 0.7, 1.0),
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.7, 1.0),

            "reg_lambda": trial.suggest_float("lambda", 0.1, 10.0, log=True),
            "reg_alpha": trial.suggest_float("alpha", 0.1, 10.0, log=True),

            "n_estimators": n_estimators,
        }

        model = xgb.XGBRegressor(**params,andom_state=42)

    # =====================================================
    #  2：RandomForest
    # =====================================================
    else:

        params = {
            "n_estimators": n_estimators,
            "max_depth": trial.suggest_int("max_depth_rf", 3, 5),
            "min_samples_split": trial.suggest_int("min_samples_split", 2, 10),
            "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 5),
            "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
            "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
        }

        model = RandomForestRegressor(
            **params,
            random_state=42,
            n_jobs=-1
        )

    # =====================================================
    #   cross validation, target: minimum MAE
    # =====================================================
    mae = -cross_val_score(
        model,
        X_train, y_train,
        scoring="neg_mean_absolute_error",
        cv=5,
        n_jobs=-1
    ).mean()

    return mae


# =====================================================
#  run optuna and start to tune hyperparameter 
# =====================================================
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=300)

print("Best model:", study.best_params["model"])
print("Best params:", study.best_params)
print("Best MAE:", study.best_value)
# Out:
# [I 2025-12-09 23:50:24,116] A new study created in memory with name: no-name-2c9a8e72-3323-47ab-95f1-708bf6e18834
# [I 2025-12-09 23:50:49,360] Trial 0 finished with value: 0.7094056646450448 and parameters: {'model': 'rf', 'n_estimators': 499, 'max_depth_rf': 4, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 0 with value: 0.7094056646450448.
# [I 2025-12-09 23:50:57,179] Trial 1 finished with value: 0.6178398535225568 and parameters: {'model': 'xgb', 'n_estimators': 593, 'eta': 0.029845622123820886, 'max_depth': 2, 'min_child_weight': 9, 'gamma': 9.030543719035483, 'subsample': 0.9685513183552277, 'colsample_bytree': 0.9642888843200249, 'lambda': 0.4690242488720859, 'alpha': 0.3345874253816728}. Best is trial 1 with value: 0.6178398535225568.
# [I 2025-12-09 23:51:04,758] Trial 2 finished with value: 0.5782766205142365 and parameters: {'model': 'xgb', 'n_estimators': 328, 'eta': 0.0150593799054111, 'max_depth': 4, 'min_child_weight': 6, 'gamma':
 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 8 with value: 0.5565199745951347.
# [I 2025-12-09 23:51:35,559] Trial 11 finished with value: 0.5524973193695982 and parameters: {'model': 'xgb', 'n_estimators': 455, 'eta': 0.09691586968873694, 'max_depth': 3, 'min_child_weight': 13, 'gamma': 0.3656937589533289, 'subsample': 0.9111607670126632, 'colsample_bytree': 0.9149174588477892, 'lambda': 6.9859514191927445, 'alpha': 9.708382085858878}. Best is trial 11 with value: 0.5524973193695982.
# [I 2025-12-09 23:51:37,274] Trial 12 finished with value: 0.5583001862979728 and parameters: {'model': 'xgb', 'n_estimators': 420, 'eta': 0.07652764216893017, 'max_depth': 3, 'min_child_weight': 13, 'gamma': 0.3423959796637116, 'subsample': 0.8991459883186588, 'colsample_bytree': 0.887196218050114, 'lambda': 0.8414852367465364, 'alpha': 9.999374495049823}. Best is trial 11 with value: 0.5524973193695982.
# [I 2025-12-09 23:51:39,118] Trial 13 finished with value: 0.5587592680585417 and parameters: {'model': 'xgb', 'n_estimators': 467, 'eta': 0.07260035715596111, 'max_depth': 3, 'min_child_weight': 12, 'gamma': 0.05354665835494754, 'subsample': 0.8926010066670964, 'colsample_bytree': 0.7970879545293545, 'lambda': 9.224858768050451, 'alpha': 2.0981203430507454}. Best is trial 11 with value: 0.5524973193695982.
# [I 2025-12-09 23:51:40,720] Trial 14 finished with value: 0.5683220169715303 and parameters: {'model': 'xgb', 'n_estimators': 392, 'eta': 0.06667604575568654, 'max_depth': 3, 'min_child_weight': 11, 'gamma': 2.36247501559755, 'subsample': 0.706499390284085, 'colsample_bytree': 0.9005744251586917, 'lambda': 2.4957926897902136, 'alpha': 8.539087238000054}. Best is trial 11 with value: 0.5524973193695982.
# [I 2025-12-09 23:51:42,447] Trial 15 finished with value: 0.5612533873151867 and parameters: {'model': 'xgb', 'n_estimators': 474, 'eta': 0.09656086941837666, 'max_depth': 3, 'min_child_weight': 15, 'gamma': 1.754530790573055, 'subsample': 0.9025093237558502, 'colsample_bytree': 0.997402336480576, 'lambda': 0.9901056184559593, 'alpha': 1.3742155431258514}. Best is trial 11 with value: 0.5524973193695982.
# [I 2025-12-09 23:51:44,566] Trial 16 finished with value: 0.5679202145311809 and parameters: {'model': 'xgb', 'n_estimators': 555, 'eta': 0.04142213704770385, 'max_depth': 3, 'min_child_weight': 11, 'gamma': 2.075781737670272, 'subsample': 0.8675270698143954, 'colsample_bytree': 0.80203785135084, 'lambda': 4.54584994451124, 'alpha': 0.10509581893874144}. Best is trial 11 with value: 0.5524973193695982.
# [I 2025-12-09 23:51:45,947] Trial 17 finished with value: 0.5848123538057711 and parameters: {'model': 'xgb', 'n_estimators': 401, 'eta': 0.08427795650239243, 'max_depth': 3, 'min_child_weight': 10, 'gamma': 6.016231912551156, 'subsample': 0.9337883623784559, 'colsample_bytree': 0.9052498477445282, 'lambda': 0.42271102026311524, 'alpha': 3.885553390470285}. Best is trial 11 with value: 0.5524973193695982.
# [I 2025-12-09 23:51:50,933] Trial 18 finished with value: 0.697254724883818 and parameters: {'model': 'rf', 'n_estimators': 368, 'max_depth_rf': 5, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': False}. Best is trial 11 with value: 0.5524973193695982.
# [I 2025-12-09 23:51:52,856] Trial 19 finished with value: 0.5714641850596258 and parameters: {'model': 'xgb', 'n_estimators': 570, 'eta': 0.06605561815639142, 'max_depth': 3, 'min_child_weight': 15, 'gamma': 3.4627328592294133, 'subsample': 0.8483994363584865, 'colsample_bytree': 0.8008939695790482, 'lambda': 1.7110568241735324, 'alpha': 0.7822750744418371}. Best is trial 11 with value: 0.5524973193695982.
# [I 2025-12-09 23:51:54,482] Trial 20 finished with value: 0.5892977228295309 and parameters: {'model': 'xgb', 'n_estimators': 459, 'eta': 0.08661167195486041, 'max_depth': 2, 'min_child_weight': 9, 'gamma': 0.9982396576732213, 'subsample': 0.7505419609494626, 'colsample_bytree': 0.8727313808623952, 'lambda': 5.833437686342123, 'alpha': 4.701235642996734}. Best is trial 11 with value: 0.5524973193695982.
# [I 2025-12-09 23
. Best is trial 277 with value: 0.5263311646735536.
# [I 2025-12-10 00:04:03,603] Trial 295 finished with value: 0.5708048118277341 and parameters: {'model': 'xgb', 'n_estimators': 551, 'eta': 0.09849930032977013, 'max_depth': 4, 'min_child_weight': 7, 'gamma': 9.69558839685336, 'subsample': 0.8953026886188862, 'colsample_bytree': 0.8944159474592217, 'lambda': 0.5172566154905166, 'alpha': 4.6751015827930225}. Best is trial 277 with value: 0.5263311646735536.
# [I 2025-12-10 00:04:05,982] Trial 296 finished with value: 0.5272318485893634 and parameters: {'model': 'xgb', 'n_estimators': 559, 'eta': 0.09989293814028627, 'max_depth': 4, 'min_child_weight': 8, 'gamma': 0.3829580699773109, 'subsample': 0.9093217695615664, 'colsample_bytree': 0.9197258630895347, 'lambda': 0.3759335493805992, 'alpha': 6.4787812065716945}. Best is trial 277 with value: 0.5263311646735536.
# [I 2025-12-10 00:04:08,079] Trial 297 finished with value: 0.5352657291752939 and parameters: {'model': 'xgb', 'n_estimators': 560, 'eta': 0.09654294774547202, 'max_depth': 4, 'min_child_weight': 8, 'gamma': 0.8277277532275534, 'subsample': 0.9113940604527146, 'colsample_bytree': 0.918939903263335, 'lambda': 0.4106456723179022, 'alpha': 6.631468660313105}. Best is trial 277 with value: 0.5263311646735536.
# [I 2025-12-10 00:04:10,319] Trial 298 finished with value: 0.5320560353599068 and parameters: {'model': 'xgb', 'n_estimators': 557, 'eta': 0.09996174657611191, 'max_depth': 4, 'min_child_weight': 8, 'gamma': 0.6311885040309733, 'subsample': 0.9107274321382371, 'colsample_bytree': 0.8998069243880704, 'lambda': 0.36974149037062587, 'alpha': 6.224768295489795}. Best is trial 277 with value: 0.5263311646735536.
# [I 2025-12-10 00:04:11,966] Trial 299 finished with value: 0.5332609256479152 and parameters: {'model': 'xgb', 'n_estimators': 333, 'eta': 0.09999967794775844, 'max_depth': 4, 'min_child_weight': 8, 'gamma': 0.3957934269732208, 'subsample': 0.8987472848850252, 'colsample_bytree': 0.8890571233412401, 'lambda': 0.38958706876079796, 'alpha': 5.4024728628175405}. Best is trial 277 with value: 0.5263311646735536.
# Best model: xgb
# Best params: {'model': 'xgb', 'n_estimators': 551, 'eta': 0.09999505543790956, 'max_depth': 4, 'min_child_weight': 7, 'gamma': 0.007863761012372683, 'subsample': 0.9073633957366012, 'colsample_bytree': 0.9023232725358237, 'lambda': 0.4625447729034002, 'alpha': 5.622304574316678}
# Best MAE: 0.5263311646735536

# %%
# tuning result, best hyperparameter combination
best_params = {
    'n_estimators': 551,
    'eta': 0.09999505543790956,
    'max_depth': 4,
    'subsample': 0.9073633957366012,
    'colsample_bytree': 0.9023232725358237,
    'min_child_weight': 7,
    'lambda': 0.4625447729034002,
    'alpha': 5.622304574316678,
    'gamma': 0.007863761012372683 
}

# train xgb model
best_model = xgb.XGBRegressor(
    **best_params,
    random_state=42
)

best_model.fit(X_train, y_train)
print("Model training completed!")


# ==========================
# train data set prediction
# ==========================
y_train_pred_log = best_model.predict(X_train)
y_train_pred = np.expm1(y_train_pred_log)
y_train_true = np.expm1(y_train)

train_mae = mean_absolute_error(y_train_true, y_train_pred)
train_rmse = np.sqrt(mean_squared_error(y_train_true, y_train_pred))


# ==========================
# test data set prediction
# ==========================
y_pred_log = best_model.predict(X_test)
y_pred = np.expm1(y_pred_log)
y_true = np.expm1(y_test)

test_mae = mean_absolute_error(y_true, y_pred)
test_rmse = np.sqrt(mean_squared_error(y_true, y_pred))


print("=======Training Set Performance=======")
print("Train MAE :", train_mae)
print("Train RMSE:", train_rmse)

print("\n=======Test Set Performance=======")
print("Test MAE :", test_mae)
print("Test RMSE:", test_rmse)

print("\n======MAE & RMSE Increase Percentage On Test dataset========")
print("MAE Increase Percentage:", round((test_mae-train_mae)/train_mae*100,2),"%")
print("RMSE Increase Percentage:", round((test_rmse-train_rmse)/train_rmse*100,2),"%")
# Out:
# Model training completed!
# =======Training Set Performance=======
# Train MAE : 17.682420651300344
# Train RMSE: 40.406710338560536
#
# =======Test Set Performance=======
# Test MAE : 20.340178665666865
# Test RMSE: 46.02946800277712
#
# ======MAE & RMSE Increase Percentage On Test dataset========
# MAE Increase Percentage: 15.03 %
# RMSE Increase Percentage: 13.92 %

# %% [markdown]
# # 4. Model Evaluation

# %%
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

mean_y = y_true.mean()
median_y = np.median(y_true)

print("MAE:", mae)
print("RMSE:", rmse)
print("mean(y):", mean_y)
print("median(y):", median_y)
print("std(y):", y_true.std())
print("MAE / mean(y):", mae / mean_y)
print("RMSE / mean(y):", rmse / mean_y)
# Out:
# MAE: 20.340178665666865
# RMSE: 46.02946800277712
# mean(y): 36.54862604540024
# median(y): 5.999999999999999
# std(y): 64.11566488601152
# MAE / mean(y): 0.5565237566085399
# RMSE / mean(y): 1.2594035120663605

# %%
# baseline prediction
y_pred_mean = np.full_like(y_true, fill_value=mean_y, dtype=float)

y_pred_median = np.full_like(y_true, fill_value=median_y, dtype=float)

for name, pred in [("mean", y_pred_mean), ("median", y_pred_median), ("model", y_pred)]:
    mae_ = mean_absolute_error(y_true, pred)
    rmse_ = np.sqrt(mean_squared_error(y_true, pred))
    print(f"{name:>6} -> MAE = {mae_:.3f}, RMSE = {rmse_:.3f}")
    
print(
    f'The trained model VS baseline predictor (mean and median): MAE decreased '
    f'{((33.6-20.224)/33.6)*100:.2f}% and RMSE decreased {((71-46)/71)*100:.2f}%'
)
# Out:
#   mean -> MAE = 45.123, RMSE = 64.116
# median -> MAE = 33.605, RMSE = 71.021
#  model -> MAE = 20.340, RMSE = 46.029
# The trained model VS baseline predictor (mean and median): MAE decreased 39.81% and RMSE decreased 35.21%

# %%
fig=plt.figure(figsize=(6,6))
plt.scatter(y_true, y_pred, alpha=0.3)
min_v = min(y_true.min(), y_pred.min())
max_v = max(y_true.max(), y_pred.max())
plt.plot([min_v, max_v], [min_v, max_v], color="red") 

plt.xlabel("Actual (hours)")
plt.ylabel("Predicted (hours)")
plt.title("Predicted vs Actual")
fig.savefig('predict&Actual.png')
plt.show()

# %%
residuals = y_true - y_pred
# Residuals Histogram
plt.figure(figsize=(6,4))
plt.hist(residuals, bins=40, alpha=0.7)
plt.title("Residuals Histogram")
plt.xlabel("Residual (y_true - y_pred)")
plt.ylabel("Count")
plt.show()

# Residuals vs predicted 
fig=plt.figure(figsize=(6,6))
plt.scatter(y_pred, residuals, alpha=0.3)
plt.axhline(0, color="red")
plt.xlabel("Predicted")
plt.ylabel("Residual")
plt.title("Residuals vs Predicted")
fig.savefig('Residual&predcited.png')
plt.show()

# %%
#QQ plot of Residuals
fig=plt.figure(figsize=(6,6))
stats.probplot(residuals, dist="norm", plot=plt)
plt.title("QQ Plot of Residuals")
fig.savefig('QQ-plot.png')
plt.show()
